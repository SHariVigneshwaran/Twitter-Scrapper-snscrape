# %% [markdown]
# # Article Notebook for Scraping Twitter Using snscrape's CLI Commands With Python
# <br>Package Github: https://github.com/JustAnotherArchivist/snscrape
#
# ### Notebook Author: Hari Vigneshwaran S
# <b>Information current as of January, 23 2023.</b><br>

# %%
# Run the pip install command below if you don't already have the library
# !pip install git+https://github.com/JustAnotherArchivist/snscrape.git

# Run the below command if you don't already have Pandas
# !pip install pandas

# Imports
import os
import pandas as pd

# %% [markdown]
# # Query by Username
# The code below will scrape for 100 tweets by a username then provide a CSV file with Pandas

# %%
# Setting variables to be used in format string command below
tweet_count = 100
username = "hari"

# Using OS library to call CLI commands in Python
os.system("snscrape --jsonl --max-results {} twitter-search 'from:{}'> user-tweets.json".format(tweet_count, username))
# Out:
# 0

# %%
# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df1 = pd.read_json('user-tweets.json', lines=True)

# Displays first 5 entries from dataframe
tweets_df1.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/hari/status/16180182110559...
# 1  https://twitter.com/hari/status/16180151968781...
# 2  https://twitter.com/hari/status/16176349081424...
# 3  https://twitter.com/hari/status/16156972684300...
# 4  https://twitter.com/hari/status/16155790024832...
#
#                        date  \
# 0 2023-01-24 22:49:37+00:00
# 1 2023-01-24 22:37:38+00:00
# 2 2023-01-23 21:26:30+00:00
# 3 2023-01-18 13:07:01+00:00
# 4 2023-01-18 05:17:04+00:00
#
#                                           rawContent  \
# 0  @RaeWynnGrant Travel pro with the “magna trac”...
# 1  @airfrance when did it become standard practic...
# 2  @satyanadella @OpenAI Maybe iron out some kink...
# 3  Tesla video promoting self-driving was staged,...
# 4  @JamesSurowiecki Like a… blockchain?\nBarcodes...
#
#                                      renderedContent                   id  \
# 0  @RaeWynnGrant Travel pro with the “magna trac”...  1618018211055951872
# 1  @airfrance when did it become standard practic...  1618015196878102528
# 2  @satyanadella @OpenAI Maybe iron out some kink...  1617634908142473216
# 3  Tesla video promoting self-driving was staged,...  1615697268430016512
# 4  @JamesSurowiecki Like a… blockchain?\nBarcodes...  1615579002483228677
#
#                                                 user  replyCount  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...           9
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...           0
#
#    retweetCount  likeCount  ...  inReplyToTweetId  \
# 0             0          1  ...      1.617985e+18
# 1             0          0  ...               NaN
# 2             0          0  ...      1.617524e+18
# 3            39         75  ...               NaN
# 4             0          0  ...      1.615507e+18
#
#                                        inReplyToUser  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...
# 1                                               None
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...
# 3                                               None
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...
#
#                                       mentionedUsers coordinates place  \
# 0  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 1  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 2  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
# 3                                               None         NaN   NaN
# 4  [{'_type': 'snscrape.modules.twitter.User', 'u...         NaN   NaN
#
#   hashtags cashtags                                               card  \
# 0     None      NaN                                               None
# 1     None      NaN                                               None
# 2     None      NaN  {'_type': 'snscrape.modules.twitter.SummaryCar...
# 3     None      NaN  {'_type': 'snscrape.modules.twitter.SummaryCar...
# 4     None      NaN                                               None
#
#    viewCount vibe
# 0      182.0  NaN
# 1        9.0  NaN
# 2     8299.0  NaN
# 3     6372.0  NaN
# 4       96.0  NaN
#
# [5 rows x 30 columns]

# %%
# Export dataframe into a CSV
tweets_df1.to_csv('user-tweets.csv', sep=',', index=False)

# %% [markdown]
# # Query by Text Search
# The code below will scrape for 500 tweets between June 1st, 2020 and July 31st, 2020, by a text search then provide a CSV file with Pandas

# %%
# Setting variables to be used in format string command below
tweet_count = 500
text_query = "house"
since_date = "2022-12-22"
until_date = "2023-01-22"

# Using OS library to call CLI commands in Python
os.system('snscrape --jsonl --max-results {} --since {} twitter-search "{} until:{}"> text-query-tweets.json'.format(tweet_count, since_date, text_query, until_date))
# Out:
# 0

# %%
# Reads the json generated from the CLI command above and creates a pandas dataframe
tweets_df2 = pd.read_json('text-query-tweets.json', lines=True)

# Displays first 5 entries from dataframe
tweets_df2.head()
# Out:
#                             _type  \
# 0  snscrape.modules.twitter.Tweet
# 1  snscrape.modules.twitter.Tweet
# 2  snscrape.modules.twitter.Tweet
# 3  snscrape.modules.twitter.Tweet
# 4  snscrape.modules.twitter.Tweet
#
#                                                  url  \
# 0  https://twitter.com/PeterCa22748591/status/161...
# 1  https://twitter.com/RyanWil62993886/status/161...
# 2  https://twitter.com/Dondee12193923/status/1616...
# 3  https://twitter.com/enzmig1/status/16169487538...
# 4  https://twitter.com/Tommy_Byrn/status/16169487...
#
#                        date  \
# 0 2023-01-21 23:59:59+00:00
# 1 2023-01-21 23:59:59+00:00
# 2 2023-01-21 23:59:59+00:00
# 3 2023-01-21 23:59:59+00:00
# 4 2023-01-21 23:59:58+00:00
#
#                                           rawContent  \
# 0  @corybernardi But we've got equity in our hous...
# 1  Think about this Microsoft sacked 12,000 from ...
# 2  @FoxNews Nancy Pelosi wants priests to perform...
# 3                        @jshiika Isso existe? Kkkkk
# 4  my main problem with Scream V is the fact that...
#
#                                      renderedContent                   id  \
# 0  @corybernardi But we've got equity in our hous...  1616948755768700929
# 1  Think about this Microsoft sacked 12,000 from ...  1616948754866929665
# 2  @FoxNews Nancy Pelosi wants priests to perform...  1616948754329833474
# 3                        @jshiika Isso existe? Kkkkk  1616948753880989696
# 4  my main problem with Scream V is the fact that...  1616948750869463041
#
#                                                 user  replyCount  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 1  {'_type': 'snscrape.modules.twitter.User', 'us...           9
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...           0
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...           1
# 4  {'_type': 'snscrape.modules.twitter.User', 'us...           2
#
#    retweetCount  likeCount  ...  inReplyToTweetId  \
# 0             0          3  ...      1.616921e+18
# 1            27         85  ...               NaN
# 2             0          0  ...      1.616932e+18
# 3             0          1  ...      1.616923e+18
# 4             0          3  ...               NaN
#
#                                        inReplyToUser  \
# 0  {'_type': 'snscrape.modules.twitter.User', 'us...
# 1                                               None
# 2  {'_type': 'snscrape.modules.twitter.User', 'us...
# 3  {'_type': 'snscrape.modules.twitter.User', 'us...
# 4                                               None
#
#                                       mentionedUsers  \
# 0  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 1                                               None
# 2  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 3  [{'_type': 'snscrape.modules.twitter.User', 'u...
# 4                                               None
#
#                                          coordinates  \
# 0                                               None
# 1                                               None
# 2                                               None
# 3                                               None
# 4  {'_type': 'snscrape.modules.twitter.Coordinate...
#
#                                                place  hashtags cashtags  card  \
# 0                                               None      None     None  None
# 1                                               None      None     None  None
# 2                                               None      None     None  None
# 3                                               None      None     None  None
# 4  {'_type': 'snscrape.modules.twitter.Place', 'i...  [Scream]     None  None
#
#    viewCount vibe
# 0       67.0  NaN
# 1     1418.0  NaN
# 2       38.0  NaN
# 3       33.0  NaN
# 4     1078.0  NaN
#
# [5 rows x 30 columns]

# %%
# Export dataframe into a CSV
tweets_df2.to_csv('text-query-tweets.csv', sep=',', index=False)
